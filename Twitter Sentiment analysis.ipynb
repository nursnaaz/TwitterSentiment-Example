# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob

class TwitterClient(object):
	'''
	Generic Twitter Class for sentiment analysis.
	'''
	def __init__(self):
		'''
		Class constructor or initialization method.
		'''
		# keys and tokens from the Twitter Dev Console
		consumer_key = 'PGKQuYtBwUa8ih5iBy80umlIj'
		consumer_secret = 'u2I5mh4llehglJt05RSN2lXnpDxqiZT3dQ0yMnsi9VW5itY2IC'
		access_token = '103894086-gQyAd64U82fU1jNW9F0vyaasetqSr0VHyqzHuzET'
		access_token_secret = 'Q6eAXmd1Qry9jq82OfmPPyeWIblwY7hnnwd97he7GZL2I'

		# attempt authentication
		try:
			# create OAuthHandler object
			self.auth = OAuthHandler(consumer_key, consumer_secret)
			# set access token and secret
			self.auth.set_access_token(access_token, access_token_secret)
			# create tweepy API object to fetch tweets
			self.api = tweepy.API(self.auth)
		except:
			print("Error: Authentication Failed")

	def clean_tweet(self, tweet):
		'''
		Utility function to clean tweet text by removing links, special characters
		using simple regex statements.
		'''
		return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

	def get_tweet_sentiment(self, tweet):
		'''
		Utility function to classify sentiment of passed tweet
		using textblob's sentiment method
		'''
		# create TextBlob object of passed tweet text
		analysis = TextBlob(self.clean_tweet(tweet))
		# set sentiment
		if analysis.sentiment.polarity > 0:
			return 'positive'
		elif analysis.sentiment.polarity == 0:
			return 'neutral'
		else:
			return 'negative'

	def get_tweets(self, query, count = 10):
		'''
		Main function to fetch tweets and parse them.
		'''
		# empty list to store parsed tweets
		tweets = []

		try:
			# call twitter api to fetch tweets
			fetched_tweets = self.api.search(q = query, count = count)

			# parsing tweets one by one
			for tweet in fetched_tweets:
				# empty dictionary to store required params of a tweet
				parsed_tweet = {}

				# saving text of tweet
				parsed_tweet['text'] = tweet.text
				# saving sentiment of tweet
				parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)

				# appending parsed tweet to tweets list
				if tweet.retweet_count > 0:
					# if tweet has retweets, ensure that it is appended only once
					if parsed_tweet not in tweets:
						tweets.append(parsed_tweet)
				else:
					tweets.append(parsed_tweet)

			# return parsed tweets
			return tweets

		except tweepy.TweepError as e:
			# print error (if any)
			print("Error : " + str(e))

def main():
	# creating object of TwitterClient Class
	api = TwitterClient()
	# calling function to get tweets
	tweets = api.get_tweets(query = 'logitech', count = 100000)

	# picking positive tweets from tweets
	ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
	# percentage of positive tweets
	print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
	# picking negative tweets from tweets
	ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
	# percentage of negative tweets
	print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
	# percentage of neutral tweets
	#print("Neutral tweets percentage: {} % ".format(100*len(tweets - ntweets - ptweets)/len(tweets)))

	# printing first 5 positive tweets
	print("\n\nPositive tweets:")
	for tweet in ptweets[:1000]:
		print(tweet['text'])

	# printing first 5 negative tweets
	print("\n\nNegative tweets:")
	for tweet in ntweets[:1000]:
		print(tweet['text'])

if __name__ == "__main__":
	# calling main function
	main()
# Out:
# Positive tweets percentage: 35.80246913580247 %
# Negative tweets percentage: 7.407407407407407 %
#
#
# Positive tweets:
# Review: Logitech Spotlight Remote the Smart Way to do a Presentation https://t.co/z24Hu0NNEZ https://t.co/KciiT3NHS0
# RT @TeamPervcb: 💕Valentine's Day Giveaway💕
# 1. Free Bio for your cam page created by @hallowin90
# 2. Logitech c920 Webcam
# 3. $50 Amazon Gift…
# Logitech MK120 | Best Budget USB 2 0 Keyboard and Mouse Combo | Data Dock: https://t.co/qLX4P6Ia1x via @YouTube
# Sorteio câmera Logitech C270! Live 01/02/2018 às 21:30hs!: https://t.co/WkEwBncVnT via @YouTube
# @Logitech Wow, this is the most appalling customer service shambles ever!
# Join the New Year Logitech G502 Proteus Spectrum RGB Tunable Gaming Mouse Giveaway by @willwork4games_ - https://t.co/Kk9kL3mtXs
# Logitech adds snapshot alerts to HomeKit-enabled Circle 2 cams with free firmware update  https://t.co/uB1tGiEkU0 https://t.co/RXNTlwrghO
# @Donzanoid I have a Logitech M705 for the lounge gaming PC and it’s been fine for playing Divinity etc on the couch… https://t.co/oEAlneJafU
# I liked a @YouTube video https://t.co/rWofCclGIf Logitech G19s Gaming Keyboard Review
# Retired my old gaming kb to office work. More than 25000 hours of gaming behind and letters are visible. @logitech https://t.co/DmfoJpSPvX
# @XtremePUBG @swedeCS Logitech are probs best imo, try go a smooth surface so, as I had a rough one and it wore down my feet quite quickly.
# RT @Bindertech: In the spotlight! With a @Logitech #Spotlight - @arcticdba is ready to go with the first #NICConf s… https://t.co/yLBX8jTJ4Q
# In the spotlight! With a @Logitech #Spotlight - @arcticdba is ready to go with the first #NICConf session of the da… https://t.co/R8z06lmP57
# I'm in the running to win an amazing #Logitech MX Master 2S - Worth £99.99 - thanks to @PrizeTopia.  #PrizeTopia… https://t.co/vYIEgte33G
# Logitech Rechargable S315i Speakers for iPod Iphone Portable Sound Travel Dock for Rs. 2764 - Ebay https://t.co/emwvkTvOck
# #HomeAutomation: Logitech Pop Smart Additional Switch white ... https://t.co/rZjGERITW7
# Me ha gustado un vídeo de @YouTube (https://t.co/ttWly69xba - HOW TO MAKE 18 SPEED TRUCK SIM SHIFTER MOD FOR LOGITECH).
# @GENOMEgg @ZOWIEGEAR @SteelSeries I have the EC2-A and it is tied for my favorite mouse with my Logitech G703. I've… https://t.co/RFbhULdLtZ
# Logitech UE Mega Boom Wireless Bluetooth Speaker Black Edition Sound Waterpro... https://t.co/QZUvbZardP
# @yanushard @oukatv Razer Black Widow always good
#
# Corsair RGB K70 or K95 are both great keyboards
#
# If you can get a… https://t.co/GP2c0cOWbw
# Logitech adds notification snapshots, whole-home subscriptions for HomeKit-enabled Circle 2 camera https://t.co/gM8y60574G #AppleNews
# Logitech adds snapshot alerts to HomeKit-enabled Circle 2 cams with free firmware update https://t.co/ZreI3XfwTz #technology
# Logitech Circle 2 Adds Notification Snapshots, Circle Safe Home Subscriptions https://t.co/2R7vfQnwn5 https://t.co/1mto10DbnF
# RT @marktpirate1: MARKT: Freundlich; feste Roche, LafargeHolcim, Credit Suisse, Zürich und Swiss Life die Fakten; im SMIM sind Logitech und…
# MARKT: Freundlich; feste Roche, LafargeHolcim, Credit Suisse, Zürich und Swiss Life die Fakten; im SMIM sind Logitech und Ams gefragt.
# Logitech adds notification snapshots, whole-home subscriptions for HomeKit-enabled Circle 2 camera… https://t.co/UaFC5zp6TD
# Logitech adds snapshot alerts to HomeKit-enabled Circle 2 cams with free firmware update https://t.co/akeL297S52 https://t.co/tWkotvJM2E
# https://t.co/M2CzIxeceO
#
# Logitech Z120 Laptop Speakers 3.5mm USB
# by Logitech
# (2451)
#
# Buy new: £12.38
# 69 used &amp; new… https://t.co/ebSjsZX8f8
# Logitech adds snapshot alerts to HomeKit-enabled Circle 2 cams with free firmware update https://t.co/hvMpivmcTB by… https://t.co/ZtZUxNQ5bW
#
#
# Negative tweets:
# RT @umzug46: 🔥Verlosung:🔥
#
# ⚡1x Sharkoon Drakonia Black (Gaming Mouse)
# 1x Auna MIC-900B (Mikrofon)
# 1x Logitech G231 Gaming-Kopfhörer⚡
#
# ✔RT…
# @Donzanoid I've been using a Logitech MX Master for the last few years now; decent weight, not too 60 sci-fi space-shipy imo
# RT @Ceogeneral: This Is The Highest Native DPI Mouse, CHECK IT OUT&gt; https://t.co/uq4BNvmcgR #game #gamer #gamers #gaming #games #videogames…
# First Logitech &amp; now Sonos, this is the future with 'everything needlessly connected to the net' products. Companie… https://t.co/Xq7j6S9nZo
# Refurbished Logitech Z130 2-Piece 3.5mm Black Compact Computer Multimedia Speaker Set https://t.co/HZ4F3xEidX https://t.co/1CfuAaOWiG
# Dear @Logitech and @Microsoft. Since neither of you respond to any other channel, would you mind getting together a… https://t.co/twRHKQNg2U
